# %%
import pandas as pd

# %%
path = "../../res/data/ManUnitedVN1878_2.csv"

# %%
df = pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['url', 'text', 'comment_count', 'share_count', 'comments_full',
#        'reactions', 'reaction_count', 'was_live', 'fetched_time',
#        'fanpage_name', 'image_count', 'has_image', 'has_with', 'date', 'time',
#        'has_link'],
#       dtype='object')

# %%
df.iloc[300:310]
# Out:
#                                                    url  \
# 300  https://facebook.com/ManUnitedVN1878/posts/784...
# 301  https://facebook.com/ManUnitedVN1878/posts/784...
# 302  https://facebook.com/ManUnitedVN1878/posts/784...
# 303  https://facebook.com/ManUnitedVN1878/posts/784...
# 304  https://facebook.com/ManUnitedVN1878/posts/784...
# 305  https://facebook.com/ManUnitedVN1878/posts/784...
# 306  https://facebook.com/ManUnitedVN1878/posts/784...
# 307  https://facebook.com/ManUnitedVN1878/posts/784...
# 308  https://facebook.com/ManUnitedVN1878/posts/784...
# 309  https://facebook.com/ManUnitedVN1878/posts/783...
#
#                                                   text  comment_count  \
# 300  MU QUYẾT SĂN ĐƯỢC TIMO WERNER. 👀\r\n\r\n👉 Theo...           45.0
# 301  Cầu thủ đối phương phạm lỗi với Greenwood khôn...           49.0
# 302  Borrusia Dortmund vừa gửi đề nghị mới tới Man ...           13.0
# 303  Sergio Reguilon sẽ trở lại Tottenham vào TTCN ...           13.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1954 entries, 0 to 1953
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             1954 non-null   object
#  1   text            1954 non-null   object
#  2   comment_count   1954 non-null   float64
#  3   share_count     1954 non-null   float64
#  4   comments_full   1954 non-null   object
#  5   reactions       1954 non-null   object
#  6   reaction_count  1954 non-null   float64
#  7   was_live        1954 non-null   bool
#  8   fetched_time    1954 non-null   object
#  9   fanpage_name    1954 non-null   object
#  10  image_count     1954 non-null   int64
#  11  has_image       1954 non-null   bool
#  12  has_with        1954 non-null   bool
#  13  date            1954 non-null   object
#  14  time            1954 non-null   object
#  15  has_link        1954 non-null   bool
# dtypes: bool(4), float64(3), int64(1), object(8)
# ...

# %%
df['url'][df.reaction_count == df.reaction_count.max()].to_list()
# Out:
# ['https://facebook.com/ManUnitedVN1878/posts/647531940750819']

# %%
df.describe()
# Out:
#        comment_count  share_count  reaction_count  image_count
# count    1954.000000  1954.000000     1954.000000  1954.000000
# mean       50.029683     2.177073      502.787615     1.021494
# std        89.228830    39.224920      772.970357     0.537911
# min         0.000000     0.000000        1.000000     0.000000
# 25%         5.000000     0.000000      109.000000     1.000000
# 50%        19.000000     0.000000      282.000000     1.000000
# 75%        57.000000     0.000000      597.250000     1.000000
# max      1450.000000  1000.000000    16623.000000     8.000000

# %%
df.columns
# Out:
# Index(['url', 'text', 'comment_count', 'share_count', 'comments_full',
#        'reactions', 'reaction_count', 'was_live', 'fetched_time',
#        'fanpage_name', 'image_count', 'has_image', 'has_with', 'date', 'time',
#        'has_link'],
#       dtype='object')

# %%
df.sort_values(by=['date', 'time'], ascending=True, inplace=True)
df.head(20)
# Out:
#                                                     url  \
# 1039  https://facebook.com/ManUnitedVN1878/posts/259...
# 1038  https://facebook.com/ManUnitedVN1878/posts/259...
# 1037  https://facebook.com/ManUnitedVN1878/posts/259...
# 1036  https://facebook.com/ManUnitedVN1878/posts/259...
# 1035  https://facebook.com/ManUnitedVN1878/posts/259...
# 1034  https://facebook.com/ManUnitedVN1878/posts/259...
# 1033  https://facebook.com/ManUnitedVN1878/posts/259...
# 1032  https://facebook.com/ManUnitedVN1878/posts/259...
# 1031  https://facebook.com/ManUnitedVN1878/posts/259...
# 1030  https://facebook.com/ManUnitedVN1878/posts/259...
# 1029  https://facebook.com/ManUnitedVN1878/posts/259...
# 1028  https://facebook.com/ManUnitedVN1878/posts/259...
# 1027  https://facebook.com/ManUnitedVN1878/posts/259...
# 1026  https://facebook.com/ManUnitedVN1878/posts/259...
# 1025  https://facebook.com/ManUnitedVN1878/posts/259...
# 1024  https://facebook.com/ManUnitedVN1878/posts/259...
# ...

# %%
import matplotlib.pyplot as plt


# Vẽ biểu đồ cột sử dụng seaborn
plt.figure(figsize=(40, 24))
plt.axhline(y = df.reaction_count.mean(), color = "r", label = "Trung bình")
df['reaction_count'].plot(kind="bar", label="")
plt.ylabel('Reaction Count')
plt.ylim(0, 5000)
plt.title('Biểu đồ thể hiện số lượt reaction theo bài viết (sắp xếp theo thứ tự thời gian)')
# plt.xticks(rotation=45)  # Xoay nhãn trục x nếu cần thiết
plt.text(x=300, y=df.reaction_count.mean(), s=f'{df.reaction_count.mean():.2f}', color="red", fontsize=20, verticalalignment='bottom')
plt.xticks([])
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Thêm lưới cho trục y
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(40, 24))
plt.axhline(y = df.comment_count.mean(), color = "r", label = "Trung bình")
df['comment_count'].plot(kind="bar", label="")
plt.ylabel('Comment Count')
plt.ylim(0, 600)
plt.title('Biểu đồ thể hiện số comment theo bài viết (sắp xếp theo thứ tự thời gian)')
# plt.xticks(rotation=45)  # Xoay nhãn trục x nếu cần thiết
plt.text(x=300, y=df.comment_count.mean(), s=f'{df.comment_count.mean():.2f}', color="red", fontsize=20, verticalalignment='bottom')
plt.xticks([])
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Thêm lưới cho trục y
plt.legend()
plt.show()

# %%
# những ngày bị thiếu
start_date = df['date'].iloc[0]
end_date = df['date'].iloc[-1]
dates = pd.date_range(start=start_date, end=end_date)
dates
# Out:
# DatetimeIndex(['2021-03-28', '2021-03-29', '2021-03-30', '2021-03-31',
#                '2021-04-01', '2021-04-02', '2021-04-03', '2021-04-04',
#                '2021-04-05', '2021-04-06',
#                ...
#                '2024-02-20', '2024-02-21', '2024-02-22', '2024-02-23',
#                '2024-02-24', '2024-02-25', '2024-02-26', '2024-02-27',
#                '2024-02-28', '2024-02-29'],
#               dtype='datetime64[ns]', length=1069, freq='D')

# %%
df['date'] = pd.to_datetime(df['date'])
all_dates = [date for date in df['date'].unique()]
zzzz = [1 if date in dates else 0 for date in all_dates]
import matplotlib.pyplot as plt
tttt = [1] * len(zzzz)

# Vẽ biểu đồ
plt.figure(figsize=(40, 12))
plt.bar(all_dates, tttt, color='skyblue')
plt.title('Những ngày xuất hiện trong data')
plt.xlabel('Ngày')
plt.yticks([])
# plt.xticks(rotation=45)  # Xoay nhãn trục x nếu cần thiết
plt.tight_layout()
plt.show()

# %%
print(len(dates))
print(len(all_dates))
# Out:
# 1069
# 455

# %%
# missing_dates = [date for date in dates if date not in all_dates]

zz = []
# print(missing_dates[0])
# print(missing_dates[0] + pd.Timedelta(days=1))
for date in all_dates:
    if (date - pd.Timedelta(days=1)) not in all_dates:
        if (date + pd.Timedelta(days=1)) in all_dates:
            zz.append((date, "Hôm trước không có bài viết, hôm sau có bài viết"))
        else:
            zz.append((date, "Hôm trước không có bài viết, hôm sau cũng không có bài viết"))
    elif (date + pd.Timedelta(days=1)) not in all_dates:
        zz.append((date, "Hôm trước có bài viết, hôm sau không có bài viết"))
zz
# Out:
# [(Timestamp('2021-03-28 00:00:00'),
#   'Hôm trước không có bài viết, hôm sau có bài viết'),
#  (Timestamp('2021-04-13 00:00:00'),
#   'Hôm trước có bài viết, hôm sau không có bài viết'),
#  (Timestamp('2021-05-23 00:00:00'),
#   'Hôm trước không có bài viết, hôm sau cũng không có bài viết'),
#  (Timestamp('2021-07-30 00:00:00'),
#   'Hôm trước không có bài viết, hôm sau cũng không có bài viết'),
#  (Timestamp('2021-09-28 00:00:00'),
#   'Hôm trước không có bài viết, hôm sau cũng không có bài viết'),
#  (Timestamp('2021-10-01 00:00:00'),
#   'Hôm trước không có bài viết, hôm sau cũng không có bài viết'),
#  (Timestamp('2021-10-29 00:00:00'),
#   'Hôm trước không có bài viết, hôm sau cũng không có bài viết'),
#  (Timestamp('2022-01-15 00:00:00'),
#   'Hôm trước không có bài viết, hôm sau có bài viết'),
#  (Timestamp('2022-05-31 00:00:00'),
#   'Hôm trước có bài viết, hôm sau không có bài viết'),
#  (Timestamp('2023-02-09 00:00:00'),
# ...

# %%
# Dữ liệu thu được cuối cùng ở ngày này, ko có gì khác
z = zz[0]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2021-03-28 00:00:00'), 'Hôm trước không có bài viết, hôm sau có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2598428443790395', 'https://facebook.com/ManUnitedVN1878/posts/2598457193787520', 'https://facebook.com/ManUnitedVN1878/posts/2598454297121143', 'https://facebook.com/ManUnitedVN1878/posts/2598455447121028', 'https://facebook.com/ManUnitedVN1878/posts/2598234973809742', 'https://facebook.com/ManUnitedVN1878/posts/2598457443787495', 'https://facebook.com/ManUnitedVN1878/posts/2598667497099823', 'https://facebook.com/ManUnitedVN1878/posts/2598611390438767', 'https://facebook.com/ManUnitedVN1878/posts/2598726927093880', 'https://facebook.com/ManUnitedVN1878/posts/2598573753775864', 'https://facebook.com/ManUnitedVN1878/posts/2598831190416787', 'https://facebook.com/ManUnitedVN1878/posts/2598821523751087', 'https://facebook.com/ManUnitedVN1878/posts/2598878190412087', 'https://facebook.com/ManUnitedVN1878/posts/2598894550410451']
# ...

# %%
# 5/6 bài viết của ngày này là dẫn link từ trang khác
# Bài cuối cùng ko dẫn link, là bài viết bình thường.
# số reaction: 189 - 10 - 27 - 155 - 44 - 1909
# Số reaction của bài viết cuối cùng gấp hơn 10 lần những bài trước.
z = zz[1]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2021-04-13 00:00:00'), 'Hôm trước có bài viết, hôm sau không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2609091879390718', 'https://facebook.com/ManUnitedVN1878/posts/2609091392724100', 'https://facebook.com/ManUnitedVN1878/posts/2609319296034643', 'https://facebook.com/ManUnitedVN1878/posts/2609349649364941', 'https://facebook.com/ManUnitedVN1878/posts/2609484786018094', 'https://facebook.com/ManUnitedVN1878/posts/2609468012686438']
#                                                     url  \
# 1920  https://facebook.com/ManUnitedVN1878/posts/260...
# 1919  https://facebook.com/ManUnitedVN1878/posts/260...
# 1918  https://facebook.com/ManUnitedVN1878/posts/260...
# 1917  https://facebook.com/ManUnitedVN1878/posts/260...
# 1916  https://facebook.com/ManUnitedVN1878/posts/260...
# 1915  https://facebook.com/ManUnitedVN1878/posts/260...
#
#                                                    text  comment_count  \
# ...

# %%
# ngày hôm trước không có bài viết
# ngày hôm sau có bài viết.
# bài đầu tiên là: alo, alo, có ai thấy tôi không :))

z = zz[2]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2021-05-23 00:00:00'), 'Hôm trước không có bài viết, hôm sau cũng không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2635487436751162', 'https://facebook.com/ManUnitedVN1878/posts/2635492686750637']
#                                                     url  \
# 1914  https://facebook.com/ManUnitedVN1878/posts/263...
# 1913  https://facebook.com/ManUnitedVN1878/posts/263...
#
#                                             text  comment_count  share_count  \
# 1914              Alo alo có ai thấy gì không…..           62.0          0.0
# 1913  Giải nghệ về làm BHL là đẹp luôn a Mata ơi           63.0          0.0
#
#                                           comments_full  \
# 1914  [{'comment_id': '2635497590083480', 'comment_u...
# 1913  [{'comment_id': '2679569192342986', 'comment_u...
#
#                                               reactions  reaction_count  \
# 1914           {'thích': 31, 'yêu thích': 4, 'buồn': 1}            36.0
# ...

# %%
z = zz[3]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2021-07-30 00:00:00'), 'Hôm trước không có bài viết, hôm sau cũng không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2682469325386306']
#                                                     url            text  \
# 1912  https://facebook.com/ManUnitedVN1878/posts/268...  ใครสวยกว่ากัน?
#
#       comment_count  share_count  \
# 1912           64.0          1.0
#
#                                           comments_full  \
# 1912  [{'comment_id': '2683208878645684', 'comment_u...
#
#                                               reactions  reaction_count  \
# 1912  {'thích': 711, 'yêu thích': 42, 'haha': 10, 'w...           766.0
#
#       was_live                fetched_time     fanpage_name  image_count  \
# 1912     False  2024-05-07 09:10:53.595505  ManUnitedVN1878            1
#
#       has_image  has_with       date      time  has_link
# 1912       True      True 2021-07-30  22:47:00     False

# %%
z = zz[4]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2021-09-28 00:00:00'), 'Hôm trước không có bài viết, hôm sau cũng không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2723029951330243']
#                                                     url  \
# 1911  https://facebook.com/ManUnitedVN1878/posts/272...
#
#                                  text  comment_count  share_count  \
# 1911  ‼Chiến đấu vì logo trên ngực áo           54.0          1.0
#
#                                           comments_full  \
# 1911  [{'comment_id': '2724774197822485', 'comment_u...
#
#                                               reactions  reaction_count  \
# 1911  {'thích': 196, 'yêu thích': 9, 'haha': 1, 'wow...           208.0
#
#       was_live                fetched_time     fanpage_name  image_count  \
# 1911     False  2024-05-07 09:10:46.704443  ManUnitedVN1878            1
#
#       has_image  has_with       date      time  has_link
# 1911       True     False 2021-09-28  03:15:00     False

# %%
z = zz[5]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2021-10-01 00:00:00'), 'Hôm trước không có bài viết, hôm sau cũng không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2724941677805737']
#                                                     url  \
# 1910  https://facebook.com/ManUnitedVN1878/posts/272...
#
#                        text  comment_count  share_count  \
# 1910  Đẳng cấp là mãi mãi ❤          160.0          0.0
#
#                                           comments_full  \
# 1910  [{'comment_id': '2737767739856464', 'comment_u...
#
#                                               reactions  reaction_count  \
# 1910  {'thích': 135, 'yêu thích': 6, 'wow': 2, 'thươ...           144.0
#
#       was_live                fetched_time     fanpage_name  image_count  \
# 1910     False  2024-05-07 09:10:32.344869  ManUnitedVN1878            1
#
#       has_image  has_with       date      time  has_link
# 1910       True     False 2021-10-01  00:05:00     False

# %%
z = zz[6]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2021-10-29 00:00:00'), 'Hôm trước không có bài viết, hôm sau cũng không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2745318495768055']
#                                                     url  \
# 1953  https://facebook.com/ManUnitedVN1878/posts/274...
#
#                                                    text  comment_count  \
# 1953  MESSENGER\r\nGiờ đây, mọi người có thể dễ dàng...           54.0
#
#       share_count                                      comments_full  \
# 1953          0.0  [{'comment_id': '2795263237440247', 'comment_u...
#
#                                reactions  reaction_count  was_live  \
# 1953  {'thích': 25, 'haha': 2, 'wow': 1}            28.0     False
#
#                     fetched_time     fanpage_name  image_count  has_image  \
# 1953  2024-05-08 20:40:22.194883  ManUnitedVN1878            0      False
#
#       has_with       date      time  has_link
# 1953     False 2021-10-29  16:58:00      True

# %%
z = zz[7]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2022-01-15 00:00:00'), 'Hôm trước không có bài viết, hôm sau có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2798144587152112', 'https://facebook.com/ManUnitedVN1878/posts/2798163893816848', 'https://facebook.com/ManUnitedVN1878/posts/2798340577132513']
#                                                     url  \
# 1909  https://facebook.com/ManUnitedVN1878/posts/279...
# 1908  https://facebook.com/ManUnitedVN1878/posts/279...
# 1907  https://facebook.com/ManUnitedVN1878/posts/279...
#
#                                                    text  comment_count  \
# 1909  Suốt 8 năm thi đấu cho Man United anh đã có:\r...            0.0
# 1908  Maguire vẫn là đội trưởng của Quỷ đỏ nhé anh e...            0.0
# 1907                              Đó sẽ là tổn thất lớn            0.0
#
#       share_count comments_full                      reactions  \
# 1909          0.0            []  {'thích': 31, 'yêu thích': 2}
# ...

# %%
# reaction: 24 - 32
# comment: 261 - 276
z = zz[8]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2022-05-31 00:00:00'), 'Hôm trước có bài viết, hôm sau không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/2891908351109068', 'https://facebook.com/ManUnitedVN1878/posts/2892069981092905']
#                                                     url  \
# 1600  https://facebook.com/ManUnitedVN1878/posts/289...
# 1599  https://facebook.com/ManUnitedVN1878/posts/289...
#
#                                                    text  comment_count  \
# 1600  Jurrien Timber, Pau Torres, Frenkie de Jong và...          261.0
# 1599                                Vẫn chỉ là tin đồn.          276.0
#
#       share_count                                      comments_full  \
# 1600          0.0  [{'comment_id': '493341612550270', 'comment_ur...
# 1599          0.0  [{'comment_id': '1173847546731443', 'comment_u...
#
#           reactions  reaction_count  was_live                fetched_time  \
# 1600  {'thích': 24}            24.0     False  2024-05-07 08:52:21.812628
# ...

# %%
# Bài viết kiểm tra tương tác

z = zz[9]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2023-02-09 00:00:00'), 'Hôm trước không có bài viết, hôm sau cũng không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/3078149872484914']
#                                                     url text  comment_count  \
# 1598  https://facebook.com/ManUnitedVN1878/posts/307...    🥰            0.0
#
#       share_count comments_full                      reactions  \
# 1598          0.0            []  {'thích': 17, 'yêu thích': 2}
#
#       reaction_count  was_live                fetched_time     fanpage_name  \
# 1598            19.0     False  2024-05-07 08:52:13.152633  ManUnitedVN1878
#
#       image_count  has_image  has_with       date      time  has_link
# 1598            1       True     False 2023-02-09  15:04:00     False

# %%
# bài viết kiểm tra tương tác
# bắt đàu viết bài lại khi thấy tương tác phục hồi

z = zz[10]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2023-04-05 00:00:00'), 'Hôm trước không có bài viết, hôm sau có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/609646287872718']
#                                                     url  \
# 1597  https://facebook.com/ManUnitedVN1878/posts/609...
#
#                                text  comment_count  share_count  \
# 1597  Chào mừng sự trở lại của Case           14.0          0.0
#
#                                           comments_full  \
# 1597  [{'comment_id': '214631471184019', 'comment_ur...
#
#                                               reactions  reaction_count  \
# 1597  {'thích': 286, 'yêu thích': 8, 'haha': 1, 'thư...           297.0
#
#       was_live                fetched_time     fanpage_name  image_count  \
# 1597     False  2024-05-07 08:52:06.974673  ManUnitedVN1878            1
#
#       has_image  has_with       date      time  has_link
# 1597       True     False 2023-04-05  20:19:00     False

# %%
# không thấy vấn đề, tại sao lại dừng nhỉ
# fanpage tạm nghỉ 1 ngày 4/6


z = zz[11]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2023-06-03 00:00:00'), 'Hôm trước có bài viết, hôm sau không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/644562134381133', 'https://facebook.com/ManUnitedVN1878/posts/644828864354460', 'https://facebook.com/ManUnitedVN1878/posts/644836801020333', 'https://facebook.com/ManUnitedVN1878/posts/644858684351478', 'https://facebook.com/ManUnitedVN1878/posts/644874537683226', 'https://facebook.com/ManUnitedVN1878/posts/644882191015794', 'https://facebook.com/ManUnitedVN1878/posts/644894134347933', 'https://facebook.com/ManUnitedVN1878/posts/644914137679266']
#                                                     url  \
# 1314  https://facebook.com/ManUnitedVN1878/posts/644...
# 1313  https://facebook.com/ManUnitedVN1878/posts/644...
# 1312  https://facebook.com/ManUnitedVN1878/posts/644...
# 1311  https://facebook.com/ManUnitedVN1878/posts/644...
# 1310  https://facebook.com/ManUnitedVN1878/posts/644...
# 1309  https://facebook.com/ManUnitedVN1878/posts/644...
# ...

# %%
# không có vấn đề gì..
# fanpage tạm nghỉ 1 ngày 4/6

z = zz[12]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2023-06-05 00:00:00'), 'Hôm trước không có bài viết, hôm sau có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/645707484266598']
#                                                     url  \
# 1306  https://facebook.com/ManUnitedVN1878/posts/645...
#
#                                                    text  comment_count  \
# 1306  💢SANCHO ĐANG CẢM THẤY KHÔNG HẠNH PHÚC TẠI MAN ...          217.0
#
#       share_count                                      comments_full  \
# 1306          0.0  [{'comment_id': '959647458683486', 'comment_ur...
#
#                                               reactions  reaction_count  \
# 1306  {'thích': 722, 'yêu thích': 3, 'haha': 118, 'w...           846.0
#
#       was_live                fetched_time     fanpage_name  image_count  \
# 1306     False  2024-05-07 00:45:36.839953  ManUnitedVN1878            1
#
#       has_image  has_with       date      time  has_link
# 1306       True     False 2023-06-05  08:28:00     False

# %%
# đăng 4 bài
# bắt đầu bị bóp tương tác, hai bài cuối chỉ có 1 like

z = zz[13]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2023-08-12 00:00:00'), 'Hôm trước có bài viết, hôm sau không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/694159329421413', 'https://facebook.com/ManUnitedVN1878/posts/694222992748380', 'https://facebook.com/ManUnitedVN1878/posts/694265352744144', 'https://facebook.com/ManUnitedVN1878/posts/694325642738115']
#                                                    url  \
# 836  https://facebook.com/ManUnitedVN1878/posts/694...
# 835  https://facebook.com/ManUnitedVN1878/posts/694...
# 834  https://facebook.com/ManUnitedVN1878/posts/694...
# 833  https://facebook.com/ManUnitedVN1878/posts/694...
#
#                                                   text  comment_count  \
# 836              Đội hình Man United cho mùa tới kiểu:           41.0
# 835  Chelsea vừa ra giá 115 triệu bảng cho Moises C...           34.0
# 834  Anh "Bảy Núi" đang đi chơi gôn ở Cheshire. Thư...            0.0
# 833                        10đ cho tinh thần của anh😍😍            0.0
#
# ...

# %%
# kiểm tra tương tác, vẫn đang bị bóp tương tác (chỉ có 1 like từ chính fanpage)

z = zz[14]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2023-08-14 00:00:00'), 'Hôm trước không có bài viết, hôm sau cũng không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/697348695769143']
#                                                    url  \
# 832  https://facebook.com/ManUnitedVN1878/posts/697...
#
#                                                   text  comment_count  \
# 832  🚩 Laurence Maguire, em trai của Harry Maguire ...            0.0
#
#      share_count comments_full    reactions  reaction_count  was_live  \
# 832          0.0            []  {'like': 1}             1.0     False
#
#                    fetched_time     fanpage_name  image_count  has_image  \
# 832  2024-05-04 18:15:46.097158  ManUnitedVN1878            1       True
#
#      has_with       date      time  has_link
# 832     False 2023-08-14  21:17:00     False

# %%
# kiểm tra tương tác, vẫn đang bị bóp tương tác (chỉ có 1 like từ chính fanpage)

z = zz[15]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2023-08-31 00:00:00'), 'Hôm trước không có bài viết, hôm sau cũng không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/709718157865530']
#                                                    url  \
# 831  https://facebook.com/ManUnitedVN1878/posts/709...
#
#                                             text  comment_count  share_count  \
# 831  Hàng thủ sao trông nó cứ hài hước ấy nhỉ? 😒            0.0          0.0
#
#     comments_full    reactions  reaction_count  was_live  \
# 831            []  {'like': 1}             1.0     False
#
#                    fetched_time     fanpage_name  image_count  has_image  \
# 831  2024-05-04 18:15:42.946006  ManUnitedVN1878            1       True
#
#      has_with       date      time  has_link
# 831     False 2023-08-31  09:31:00     False

# %%
# chỉ đăng 1 bài viết, kiểm tra tương tác
# bắt đầu phục hồi tương tác

z = zz[16]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2023-09-19 00:00:00'), 'Hôm trước không có bài viết, hôm sau có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/721037763400236']
#                                                    url  \
# 830  https://facebook.com/ManUnitedVN1878/posts/721...
#
#                                                   text  comment_count  \
# 830  ❌ 4 mùa đầu tiên của Klopp: Xếp thứ 8️⃣, 4️⃣, ...           17.0
#
#      share_count                                      comments_full  \
# 830          0.0  [{'comment_id': '693289218964066', 'comment_ur...
#
#                    reactions  reaction_count  was_live  \
# 830  {'like': 96, 'haha': 3}            99.0     False
#
#                    fetched_time     fanpage_name  image_count  has_image  \
# 830  2024-05-04 18:15:36.146829  ManUnitedVN1878            1       True
#
#      has_with       date      time  has_link
# 830     False 2023-09-19  10:20:00     False

# %%
# dừng, ko biết lý do tại sao

z = zz[17]
print(z)
print(df['url'][df['date'] == z[0]].to_list())
df[df['date'] == z[0]]
# Out:
# (Timestamp('2024-02-29 00:00:00'), 'Hôm trước có bài viết, hôm sau không có bài viết')
# ['https://facebook.com/ManUnitedVN1878/posts/820515010119177', 'https://facebook.com/ManUnitedVN1878/posts/820531643450847', 'https://facebook.com/ManUnitedVN1878/posts/820583643445647', 'https://facebook.com/ManUnitedVN1878/posts/820697913434220', 'https://facebook.com/ManUnitedVN1878/posts/820755743428437']
#                                                  url  \
# 4  https://facebook.com/ManUnitedVN1878/posts/820...
# 3  https://facebook.com/ManUnitedVN1878/posts/820...
# 2  https://facebook.com/ManUnitedVN1878/posts/820...
# 1  https://facebook.com/ManUnitedVN1878/posts/820...
# 0  https://facebook.com/ManUnitedVN1878/posts/820...
#
#                                                 text  comment_count  \
# 4  Manchester United sẽ gặp Liverpool ở lượt đấu ...           49.0
# 3  Ngay khi tình huống này xảy ra, mình đã nhớ về...           53.0
# ...
